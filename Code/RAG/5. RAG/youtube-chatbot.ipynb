# %%
# pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-1.2.3-py3-none-any.whl.metadata (24 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from youtube-transcript-api)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: requests in c:\users\saree\desktop\learnings\genai\code\venv\lib\site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saree\desktop\learnings\genai\code\venv\lib\site-packages (from requests->youtube-transcript-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saree\desktop\learnings\genai\code\venv\lib\site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saree\desktop\learnings\genai\code\venv\lib\site-packages (from requests->youtube-transcript-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saree\desktop\learnings\genai\code\venv\lib\site-packages (from requests->youtube-transcript-api) (2025.10.5)
# Downloading youtube_transcript_api-1.2.3-py3-none-any.whl (485 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: defusedxml, youtube-transcript-api
#
#    ---------------------------------------- 0/2 [defusedxml]
#    ---------------------------------------- 0/2 [defusedxml]
#    -------------------- ------------------- 1/2 [youtube-transcript-api]
#    -------------------- ------------------- 1/2 [youtube-transcript-api]
#    -------------------- ------------------- 1/2 [youtube-transcript-api]
#    -------------------- ------------------- 1/2 [youtube-transcript-api]
#    ---------------------------------------- 2/2 [youtube-transcript-api]
#
# Successfully installed defusedxml-0.7.1 youtube-transcript-api-1.2.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Install Libraries

# %%
from youtube_transcript_api import YouTubeTranscriptApi,TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import ChatGoogleGenerativeAI,GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ### Step 1a. Indexing ( Document Ingestion)

# %%
video_id='zYCWvbtAE1Q' # Get the video id from the youtube url

# X0btK9X0Xnk
# ngvOyccUzzY ( David Goggins )

try:
    transcript_list=YouTubeTranscriptApi().fetch(video_id=video_id,languages=['hi'])

    transcript=" ".join(chunk['text'] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video")
